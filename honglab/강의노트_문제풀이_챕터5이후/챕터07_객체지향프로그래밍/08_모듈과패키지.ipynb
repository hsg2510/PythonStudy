# %% [markdown]
# ___
# <a href='https://cafe.naver.com/jmhonglab'><p style="text-align:center;"><img src='https://lh3.googleusercontent.com/lY3ySXooSmwsq5r-mRi7uiypbo0Vez6pmNoQxMFhl9fmZJkRHu5lO2vo7se_0YOzgmDyJif9fi4_z0o3ZFdwd8NVSWG6Ea80uWaf3pOHpR4GHGDV7kaFeuHR3yAjIJjDgfXMxsvw=w2400'  class="center" width="50%" height="50%"/></p></a>
# ___
# <center><em>Content Copyright by HongLab, Inc.</em></center>

# %% [markdown]
# ### 모듈 만들고 사용하기
#
# - 모듈로 만들고 싶은 내용들을 OOOO.py 파일에 넣고 import OOOO
# - 주의: 주피터 노트북에서는 모듈 파일을 수정한 후에는 커널을 restart를 해줘야 수정된 내용이 반영됩니다. 스크립트모드에서는 상관없습니다.

# %%
my_var = "my_var"

def my_func():
    print("__name__=", __name__)

class MyClass():
    def work(self):
        print("MyClass")

# %% [markdown]
# ### 패키지 만들고 사용하기
#
# 폴더를 만들고 그 안에 ```__init__.py``` 파일과 모듈 파일들을 넣으면 됩니다.

# %%
import my_package.my_module1 as mm1 
import my_package.my_module2 as mm2 
import my_package as m
# import my_package.sub_package.sub_module as sm
print(dir(m))

mm1.my_func1()
mm2.my_func2()
# m.sub_func() #여기서 에러가 나는데, .py 파일로 하면 에러가 안남 .ipynb 파일이 패키지 import 에러가 있나봄. package_module_test.py 파일 만들어서 테스트 해봄
# Out:
# ['__builtins__', '__cached__', '__doc__', '__file__', '__loader__', '__name__', '__package__', '__path__', '__spec__', 'my_module1', 'my_module2']
# my_func1
# my_func2
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[14], line 9
#       7 mm1.my_func1()
#       8 mm2.my_func2()
# ----> 9 m.sub_func()
#
# AttributeError: module 'my_package' has no attribute 'sub_func'
